# %%
from sklearn.model_selection import train_test_split
from utils import *

# %%
chips_path = './data/chips.csv'
geyser_path = './data/geyser.csv'
depth = 2
steps = [1, 2, 3, 5, 8, 13, 21, 34, 55]
test_size = 0.3

# %%
X_chips, Y_chips = read_data(chips_path)

X_chips_train, X_chips_test, Y_chips_train, Y_chips_test = train_test_split(X_chips, Y_chips, test_size=test_size,
                                                                            random_state=42)

clf_chips = AdaBoost(depth, DecisionTree)

# clf_chips.fit(X_chips, Y_chips)
clf_chips.fit(X_chips_train, Y_chips_train)

# %%
X_geyser, Y_geyser = read_data(geyser_path)

X_geyser_train, X_geyser_test, Y_geyser_train, Y_geyser_test = train_test_split(X_geyser, Y_geyser, test_size=test_size,
                                                                                random_state=42)

clf_geyser = AdaBoost(depth, DecisionTree)

# clf_geyser.fit(X_geyser, Y_geyser)
clf_geyser.fit(X_geyser_train, Y_geyser_train)

# %%
draw_accuracy(X_chips, Y_chips, clf_chips)
# Out:
# 100%|██████████| 55/55 [00:00<00:00, 125.63it/s]

# %%
draw_accuracy(X_geyser, Y_geyser, clf_geyser)
# Out:
# 100%|██████████| 55/55 [00:00<00:00, 73.32it/s]

# %%
draw_all_ada(X_chips, Y_chips, clf_chips, steps)

# %%
draw_all_ada(X_geyser, Y_geyser, clf_geyser, steps)
